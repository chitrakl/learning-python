# %% [markdown]
# #Lists

# %% [markdown]
# ##A list is a sequence

# %% [markdown]
# Like a string, a list is a sequence of values. In a string, the values are characters; in a list, they can be any type. The values in a list are called elements.

# %%
numbers = [12 , 13]       #list of integers

# %%
ribbons = [ 'white' , 'pink' , 'red']     #list of ribbon colours

# %% [markdown]
# The elements of a list don’t have to be the same type. The following list contains a string, a float, an integer, and even another list.

# %%
t = ['spam' , 12 , 13 , 2.1 , [1 , 3]]    #A list within another list is nested.

# %% [markdown]
# A list that contains no elements is called an empty list; you can create one with empty brackets, [].

# %%
empty = []

# %% [markdown]
# The len function returns the length of a list.

# %%
len(numbers)
# Out:
# 2

# %%
len(t)
# Out:
# 5

# %%
len(empty)
# Out:
# 0

# %% [markdown]
# ##Lists are mutable

# %% [markdown]
# To read an element of a list, we can use the bracket operator. The index of the first element is 0.

# %%
numbers[0]
# Out:
# 12

# %%
t[3]
# Out:
# 2.1

# %% [markdown]
# lists are mutable. When the bracket operator appears on the left side of an assignment, it identifies the element of the list that will be assigned.

# %%
numbers[1] = 15
numbers
# Out:
# [12, 15]

# %% [markdown]
# The in operator works on lists – it checks whether a given element appears anywhere in the list.

# %%
t
# Out:
# ['spam', 12, 13, 2.1, [1, 3]]

# %%
'spam' in t
# Out:
# True

# %% [markdown]
# Although a list can contain another list, the nested list still counts as a single element – so in the following list, there are only five elements.

# %%
len(t)
# Out:
# 5

# %% [markdown]
# And 1 is not considered to be an element of t because it is an element of a nested list, not t.

# %%
1 in t
# Out:
# False

# %% [markdown]
# ## List slices

# %% [markdown]
# The slice operator works on lists the same way it works on strings. The following example selects the second and third elements from a list of four letters.

# %%
letters = ['a', 'b', 'c', 'd']
letters[1:3]
# Out:
# ['b', 'c']

# %% [markdown]
# If you omit the first index, the slice starts at the beginning.

# %%
letters[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# If you omit the second, the slice goes to the end.

# %%
letters[2:]
# Out:
# ['c', 'd']

# %% [markdown]
# So if you omit both, the slice is a copy of the whole list.

# %%
letters[:]
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Another way to copy a list is to use the list function.

# %%
list(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Because list is the name of a built-in function, you should avoid using it as a variable name.

# %% [markdown]
# ##List operations

# %% [markdown]
# The + operator concatenates lists.

# %%
v1 = [1,2]
v2 = [3,4]
v1 + v2
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# The * operator repeats a list a given number of times.

# %%
['spam']*4
# Out:
# ['spam', 'spam', 'spam', 'spam']

# %% [markdown]
# No other mathematical operators work with lists, but the built-in function sum adds up the elements.

# %%
sum(v1)
# Out:
# 3

# %%
sum(v2)
# Out:
# 7

# %% [markdown]
# And min and max find the smallest and largest elements.

# %%
min(v1)
# Out:
# 1

# %%
max(v1)
# Out:
# 2

# %% [markdown]
# ##List methods

# %% [markdown]
# Python provides methods that operate on lists. For example, append adds a new element to the end of a list:

# %%
letters.append('e')
letters
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# extend takes a list as an argument and appends all of the elements:

# %%
letters.extend(['f' , 'g' , 'h'])
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %% [markdown]
# There are two methods that remove elements from a list. If you know the index of the element you want, you can use pop.

# %%
t = ['a' , 'b' , 'c']
t.pop(1)
# Out:
# 'b'

# %%
t
# Out:
# ['a', 'c']

# %% [markdown]
# If you know the element you want to remove (but not the index), you can use remove:

# %%
p = ['a' , 'b' , 'c']
p.remove('b')
p
# Out:
# ['a', 'c']

# %% [markdown]
# If the element you ask for is not in the list, that’s a ValueError.

# %%
p.remove('d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2386/1370473024.py in <cell line: 0>()
# ----> 1 p.remove('d')
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ## Lists and strings

# %% [markdown]
# A string is a sequence of characters and a list is a sequence of values, but a list of characters is not the same as a string. To convert from a string to a list of characters, you can use the list function.

# %%
s = 'spam'
t = list(s)
t
# Out:
# ['s', 'p', 'a', 'm']

# %% [markdown]
# The list function breaks a string into individual letters. If you want to break a string into words, you can use the split method:

# %%
from re import split
r = 'this is a boat'
p = r.split()
p
# Out:
# ['this', 'is', 'a', 'boat']

# %% [markdown]
# An optional argument called a delimiter specifies which characters to use as word boundaries. The following example uses a hyphen as a delimiter.

# %%
x = 'ex-bestfriend'
y = x.split('-')
y
# Out:
# ['ex', 'bestfriend']

# %% [markdown]
# If you have a list of strings, you can concatenate them into a single string using join. join is a string method, so you have to invoke it on the delimiter and pass the list as an argument.

# %%
delimiter = ' '
t = ['Parrot' , 'likes','green chillies.']
z = delimiter.join(t)
z
# Out:
# 'Parrot likes green chillies.'

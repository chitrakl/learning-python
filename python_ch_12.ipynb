# %% [markdown]
# # Study Text Analysis and Generation

# %% [markdown]
# ## Unique-words

# %%
filename = 'dr_jekyll.txt'

# %%
unique_words = {}
for line in open(filename):
    seq = line.split()
    for word in seq:
        unique_words[word] = 1

len(unique_words)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 unique_words = {}
# ----> 2 for line in open(filename):
#       3     seq = line.split()
#       4     for word in seq:
#       5         unique_words[word] = 1
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dr_jekyll.txt'
